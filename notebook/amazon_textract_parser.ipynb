# %%
import csv
import json
import re

# %%
from trp.trp2_analyzeid import TAnalyzeIdDocument, TAnalyzeIdDocumentSchema
from trp import Document

# %%
filename = '/home/lap-49/Documents/ot-report/outputs/aws_pedieat_page_merged.json'
raw_data = ""

with open(filename, 'r') as f:
    raw_data = f.read()

# %%
json_response = json.loads(raw_data)

# %%
doc = Document(json_response)


columns = ['Observations', 'Never', 'Almost Never', "Sometimes", 'Often', 'Almost Always', 'Always', "Score"]

csv_dict: dict = {}
csv_data = []

with open('output.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    for page in doc.pages:
        for table in page.tables:
            for row in table.rows:
                d = {col: cell.text for col, cell in zip(columns, row.cells)}
                csv_data.append(d)
                writer.writerow(csv_data)

# %%
scores = {
    "Never": "0",
    "Almost Never": "1",
    "Sometimes": "2",
    "Often": "3",
    "Almost Always": "4",
    "Always": "5"
}
scores_reverse = {
    "Never": "5",
    "Almost Never": "4",
    "Sometimes": "3",
    "Often": "2",
    "Almost Always": "1",
    "Always": "0"
}

# %%
def get_selected(text):
    matches = re.findall(r'\b[A-Z]+\b', text)
    return matches[0]

# %%
csv_data
# Out:
# [{'Observations': '',
#   'Never': '0 ',
#   'Almost Never': '1 ',
#   'Sometimes': '2 ',
#   'Often': '3 ',
#   'Almost Always': '4 ',
#   'Always': '5 ',
#   'Score': ''},
#  {'Observations': 'My child. ',
#   'Never': 'Never ',
#   'Almost Never': 'Almost Never ',
#   'Sometimes': 'Sometimes ',
#   'Often': 'Often ',
#   'Almost Always': 'Almost Always ',
#   'Always': 'Always ',
#   'Score': 'Score '},
#  {'Observations': '1. gets watery eyes when eating ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '2. gets red color around eyes or face when eating ',
#   'Never': 'SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '3. coughs during or after eating ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': 'sounds gurgly or like they need to cough or clear their throat during or after 4. eating ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': 'sounds different during or after a meal (for example, voice becomes hoarse, 5. high-pitched, or quiet) ',
#   'Never': 'SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '6. chokes or coughs on water or other thin liquids ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '7. moves head down toward chest when swallowing ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '8. has food or liquid come out of nose when eating ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '9. gets pale or blue color around his/her lips during meals ',
#   'Never': 'SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '10. breathes faster or harder when eating ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '11. needs to take a break during the meal to rest or catch their breath ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'SELECTED, ',
#   'Score': ''},
#  {'Observations': '12. gets tired from eating and is not able to finish ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '13. sweats/gets clammy during meals ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '14. tilts head back while eating ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '15. burps more than usual while eating ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '16. throws up during mealtime ',
#   'Never': 'SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': 'throws up between meals (from 30 minutes after the last meal until the next 17. meal) ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '18. arches back during or after meals ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '',
#   'Never': '0 ',
#   'Almost Never': '1 ',
#   'Sometimes': '2 ',
#   'Often': '3 ',
#   'Almost Always': '4 ',
#   'Always': '5 ',
#   'Score': ''},
#  {'Observations': 'My child ',
#   'Never': 'Never ',
#   'Almost Never': 'Almost Never ',
#   'Sometimes': 'Sometimes ',
#   'Often': 'Often ',
#   'Almost Always': 'Almost Always ',
#   'Always': 'Always ',
#   'Score': 'Score '},
#  {'Observations': 'gags when it is time to eat (for example, when they see food or when placed in 19. high chair) ',
#   'Never': 'SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '20. gags with smooth foods like pudding ',
#   'Never': 'SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '21. gags with textured food like coarse oatmeal ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': 'gags, coughs, or vomits when brushing teeth (if your child does not have teeth, 22. select Never. If your child will not allow you to brush his/her teeth, select Always) ',
#   'Never': 'SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '23. gets a bloated tummy after eating ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '24. turns red in face, may cry with stooling ',
#   'Never': 'SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '25. has gas ',
#   'Never': 'SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '26. drools when eating ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '27. has a hard time eating due to stuffy nose ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'SELECTED, ',
#   'Score': ''},
#  {'Observations': '',
#   'Never': '0 ',
#   'Almost Never': '1 ',
#   'Sometimes': '2 ',
#   'Often': '3 ',
#   'Almost Always': '4 ',
#   'Always': '5 ',
#   'Score': ''},
#  {'Observations': 'My child ',
#   'Never': 'Never ',
#   'Almost Never': 'Almost Never ',
#   'Sometimes': 'Sometimes ',
#   'Often': 'Often ',
#   'Almost Always': 'Almost Always ',
#   'Always': 'Always ',
#   'Score': 'Score '},
#  {'Observations': '28. avoids eating by playing or talking ',
#   'Never': 'SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '29. has to be told to start eating ',
#   'Never': 'SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '30. has to be reminded to keep eating ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': "31. won't eat at meals, but wants food later ",
#   'Never': 'SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '32. stops eating after a few bites ',
#   'Never': 'SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '33. refuses to eat ',
#   'Never': 'SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': 'shows more stress during meals than during non-meal times (whines, cries, 34. gets angry, tantrums) ',
#   'Never': 'SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '35. likes something one day and not the next ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '',
#   'Never': '0 ',
#   'Almost Never': '1 ',
#   'Sometimes': '2 ',
#   'Often': '3 ',
#   'Almost Always': '4 ',
#   'Always': '5 ',
#   'Score': ''},
#  {'Observations': 'My child ',
#   'Never': 'Never ',
#   'Almost Never': 'Almost Never ',
#   'Sometimes': 'Sometimes ',
#   'Often': 'Often ',
#   'Almost Always': 'Almost Always ',
#   'Always': 'Always ',
#   'Score': 'Score '},
#  {'Observations': 'insists on food being offered in a certain way (such as, how food is on the plate 36. or what dish or spoon is used, or where they sit) ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '37. insists on being fed by the same person(s) ',
#   'Never': 'SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '38. becomes upset by the smell of food ',
#   'Never': 'SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '39. throws food or pushes food away ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '40. prefers to drink instead of eat ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '41. prefers crunchy foods ',
#   'Never': 'SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '42. eats better when entertained ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '43. takes more than 30 minutes to eat ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '44. needs mealtime to be calm ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '45. wants the same food for more than two weeks in a row ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': 'Items below are scored according to the numbers at right ',
#   'Never': '5 ',
#   'Almost Never': '4 ',
#   'Sometimes': '3 ',
#   'Often': '2 ',
#   'Almost Always': '1 ',
#   'Always': '0 ',
#   'Score': ''},
#  {'Observations': '',
#   'Never': 'Never ',
#   'Almost Never': 'Almost Never ',
#   'Sometimes': 'Sometimes ',
#   'Often': 'Often ',
#   'Almost Always': 'Almost Always ',
#   'Always': 'Always ',
#   'Score': ''},
#  {'Observations': '46. likes to eat ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'SELECTED, ',
#   'Score': ''},
#  {'Observations': '47. eats a variety of foods (fruits, vegetables, proteins, etc.) ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'SELECTED, ',
#   'Score': ''},
#  {'Observations': '48. is willing to stay seated during mealtime ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'SELECTED, ',
#   'Score': ''},
#  {'Observations': '49. opens their mouth when food is offered ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'SELECTED, ',
#   'Score': ''},
#  {'Observations': '50. is willing to touch food with their hands ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'SELECTED, ',
#   'Score': ''},
#  {'Observations': '',
#   'Never': '5 ',
#   'Almost Never': '4 ',
#   'Sometimes': '3 ',
#   'Often': '2 ',
#   'Almost Always': '1 ',
#   'Always': '0 ',
#   'Score': ''},
#  {'Observations': 'My child ',
#   'Never': 'Never ',
#   'Almost Never': 'Almost Never ',
#   'Sometimes': 'Sometimes ',
#   'Often': 'Often ',
#   'Almost Always': 'Almost Always ',
#   'Always': 'Always ',
#   'Score': 'Score '},
#  {'Observations': '51. will eat mixed texture foods ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'SELECTED, ',
#   'Score': ''},
#  {'Observations': '52. will eat food warmer than room temperature ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'SELECTED, ',
#   'Score': ''},
#  {'Observations': '53. is willing to feed self (if younger in age, holds cup, feeds self crackers) ',
#   'Never': 'SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '54. keeps food in mouth when eating (food means non-liquids) ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '55. keeps liquids in mouth when drinking ',
#   'Never': 'SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '56. keeps their tongue inside mouth during eating ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '57. acts hungry before meals ',
#   'Never': 'SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '',
#   'Never': '5 ',
#   'Almost Never': '4 ',
#   'Sometimes': '3 ',
#   'Often': '2 ',
#   'Almost Always': '1 ',
#   'Always': '0 ',
#   'Score': ''},
#  {'Observations': 'For the following items, if your child is younger than 15 months and is not offered these foods, select Always. If your child is over 15 months and not offered these foods or refuses to eat these foods, select Never. ',
#   'Never': 'Never ',
#   'Almost Never': 'Almost Never ',
#   'Sometimes': 'Sometimes ',
#   'Often': 'Often ',
#   'Almost Always': 'Almost Always ',
#   'Always': 'Always ',
#   'Score': 'Score '},
#  {'Observations': '58. will eat foods that need to be chewed ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '59. will eat textured food like coarse oatmeal ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '60. will eat frozen food, like ice cream ',
#   'Never': 'SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '61. chews their food enough ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '62. moves food in their mouth when chewing without help ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': 'are ',
#   'Never': '0 ',
#   'Almost Never': '1 ',
#   'Sometimes': '2 ',
#   'Often': '3 ',
#   'Almost Always': '4 ',
#   'Always': '5 ',
#   'Score': ''},
#  {'Observations': '',
#   'Never': 'Never ',
#   'Almost Never': 'Almost Never ',
#   'Sometimes': 'Sometimes ',
#   'Often': 'Often ',
#   'Almost Always': 'Almost Always ',
#   'Always': 'Always ',
#   'Score': 'Score '},
#  {'Observations': '63. sniffs food or objects ',
#   'Never': 'SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '64. spits food out ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '65. eats too fast ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '',
#   'Never': '',
#   'Almost Never': '',
#   'Sometimes': '',
#   'Often': '',
#   'Almost Always': '',
#   'Always': '',
#   'Score': ''},
#  {'Observations': 'My child ',
#   'Never': 'Never ',
#   'Almost Never': 'Almost Never ',
#   'Sometimes': 'Sometimes ',
#   'Often': 'Often ',
#   'Almost Always': 'Almost Always ',
#   'Always': 'Always ',
#   'Score': 'Score '},
#  {'Observations': '66. stores food in their cheek or roof of mouth ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '67. gets food stuck in their cheek or roof of mouth ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '68. prefers smooth foods like yogurt ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '69. puts too much food in mouth at one time ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '70. puts fingers in mouth to move food ',
#   'Never': 'SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '71. prefers strong flavors ',
#   'Never': 'SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '72. bites down on the spoon or fork and does not release it easily ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': 'grinds teeth when awake (if your child does not have teeth, please select 73. Never. ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '74. chews on toys, clothes, or other objects ',
#   'Never': 'SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': 'Items below are scored according to the numbers at right ',
#   'Never': '0 ',
#   'Almost Never': '1 ',
#   'Sometimes': '2 ',
#   'Often': '3 ',
#   'Almost Always': '4 ',
#   'Always': '5 ',
#   'Score': ''},
#  {'Observations': 'For the following items, if your child is younger than 15 months and is not offered chewable foods, select Never. If your child is over 15 months and not offered these foods or refuses to eat these foods, select Always. ',
#   'Never': 'Never ',
#   'Almost Never': 'Almost Never ',
#   'Sometimes': 'Sometimes ',
#   'Often': 'Often ',
#   'Almost Always': 'Almost Always ',
#   'Always': 'Always ',
#   'Score': 'Score '},
#  {'Observations': '75. has to be reminded to chew food ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '76. sucks on food to soften or moisten it, rather than chewing it ',
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': "77. chews food but doesn't swallow it ",
#   'Never': 'NOT_SELECTED, ',
#   'Almost Never': 'SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''},
#  {'Observations': '78. chews a bite of food for a long time (~30 seconds or longer) ',
#   'Never': 'SELECTED, ',
#   'Almost Never': 'NOT_SELECTED, ',
#   'Sometimes': 'NOT_SELECTED, ',
#   'Often': 'NOT_SELECTED, ',
#   'Almost Always': 'NOT_SELECTED, ',
#   'Always': 'NOT_SELECTED, ',
#   'Score': ''}]

# %%
# t_doc = TAnalyzeIdDocument().load(json.loads(raw_data))
observation_scores = []

for d in csv_data:
    l = []
    for k, v in d.items():
        if v == '': break
        if k == 'Score': continue
        if k == 'Observations':
            l.append(v)
        if "SELECTED" in d[k] and 'NOT_SELECTED' not in d[k]:
            if get_selected(v) == "SELECTED":
                l.append(scores[k])
    if l and not len(l) == 1:
        observation_scores.append(l)

# %%
observation_scores
# Out:
# [['1. gets watery eyes when eating ', '2'],
#  ['2. gets red color around eyes or face when eating ', '0'],
#  ['3. coughs during or after eating ', '2'],
#  ['sounds gurgly or like they need to cough or clear their throat during or after 4. eating ',
#   '1'],
#  ['sounds different during or after a meal (for example, voice becomes hoarse, 5. high-pitched, or quiet) ',
#   '0'],
#  ['6. chokes or coughs on water or other thin liquids ', '2'],
#  ['7. moves head down toward chest when swallowing ', '2'],
#  ['8. has food or liquid come out of nose when eating ', '4'],
#  ['9. gets pale or blue color around his/her lips during meals ', '0'],
#  ['10. breathes faster or harder when eating ', '1'],
#  ['11. needs to take a break during the meal to rest or catch their breath ',
#   '5'],
#  ['12. gets tired from eating and is not able to finish ', '1'],
#  ['13. sweats/gets clammy during meals ', '1'],
#  ['14. tilts head back while eating ', '1'],
#  ['15. burps more than usual while eating ', '1'],
#  ['16. throws up during mealtime ', '0'],
#  ['throws up between meals (from 30 minutes after the last meal until the next 17. meal) ',
#   '1'],
#  ['18. arches back during or after meals ', '2'],
#  ['gags when it is time to eat (for example, when they see food or when placed in 19. high chair) ',
#   '0'],
#  ['20. gags with smooth foods like pudding ', '0'],
#  ['21. gags with textured food like coarse oatmeal ', '1'],
#  ['gags, coughs, or vomits when brushing teeth (if your child does not have teeth, 22. select Never. If your child will not allow you to brush his/her teeth, select Always) ',
#   '0'],
#  ['23. gets a bloated tummy after eating ', '1'],
#  ['24. turns red in face, may cry with stooling ', '0'],
#  ['25. has gas ', '0'],
#  ['26. drools when eating ', '3'],
#  ['27. has a hard time eating due to stuffy nose ', '5'],
#  ['28. avoids eating by playing or talking ', '0'],
#  ['29. has to be told to start eating ', '0'],
#  ['30. has to be reminded to keep eating ', '3'],
#  ["31. won't eat at meals, but wants food later ", '0'],
#  ['32. stops eating after a few bites ', '0'],
#  ['33. refuses to eat ', '0'],
#  ['shows more stress during meals than during non-meal times (whines, cries, 34. gets angry, tantrums) ',
#   '0'],
#  ['insists on food being offered in a certain way (such as, how food is on the plate 36. or what dish or spoon is used, or where they sit) ',
#   '3'],
#  ['37. insists on being fed by the same person(s) ', '0'],
#  ['38. becomes upset by the smell of food ', '0'],
#  ['39. throws food or pushes food away ', '3'],
#  ['40. prefers to drink instead of eat ', '1'],
#  ['41. prefers crunchy foods ', '0'],
#  ['42. eats better when entertained ', '2'],
#  ['43. takes more than 30 minutes to eat ', '2'],
#  ['44. needs mealtime to be calm ', '2'],
#  ['45. wants the same food for more than two weeks in a row ', '1'],
#  ['46. likes to eat ', '5'],
#  ['47. eats a variety of foods (fruits, vegetables, proteins, etc.) ', '5'],
#  ['48. is willing to stay seated during mealtime ', '5'],
#  ['49. opens their mouth when food is offered ', '5'],
#  ['50. is willing to touch food with their hands ', '5'],
#  ['51. will eat mixed texture foods ', '5'],
#  ['52. will eat food warmer than room temperature ', '5'],
#  ['53. is willing to feed self (if younger in age, holds cup, feeds self crackers) ',
#   '0'],
#  ['54. keeps food in mouth when eating (food means non-liquids) ', '2'],
#  ['55. keeps liquids in mouth when drinking ', '0'],
#  ['56. keeps their tongue inside mouth during eating ', '1'],
#  ['57. acts hungry before meals ', '0'],
#  ['58. will eat foods that need to be chewed ', '3'],
#  ['59. will eat textured food like coarse oatmeal ', '2'],
#  ['60. will eat frozen food, like ice cream ', '0'],
#  ['61. chews their food enough ', '1'],
#  ['62. moves food in their mouth when chewing without help ', '3'],
#  ['63. sniffs food or objects ', '0'],
#  ['64. spits food out ', '3'],
#  ['65. eats too fast ', '2'],
#  ['66. stores food in their cheek or roof of mouth ', '2'],
#  ['67. gets food stuck in their cheek or roof of mouth ', '1'],
#  ['68. prefers smooth foods like yogurt ', '1'],
#  ['69. puts too much food in mouth at one time ', '1'],
#  ['70. puts fingers in mouth to move food ', '0'],
#  ['71. prefers strong flavors ', '0'],
#  ['72. bites down on the spoon or fork and does not release it easily ', '3'],
#  ['grinds teeth when awake (if your child does not have teeth, please select 73. Never. ',
#   '1'],
#  ['74. chews on toys, clothes, or other objects ', '0'],
#  ['75. has to be reminded to chew food ', '2'],
#  ['76. sucks on food to soften or moisten it, rather than chewing it ', '3'],
#  ["77. chews food but doesn't swallow it ", '1'],
#  ['78. chews a bite of food for a long time (~30 seconds or longer) ', '0']]

# %%
# Out:
# gets watery eyes when eating
# gets red color around eyes or face when eating
# coughs during or after eating
# sounds gurgly or like they need to cough or clear their throat during or after 4. eating
# sounds different during or after a meal (for example, voice becomes hoarse, 5. high-pitched, or quiet)
# chokes or coughs on water or other thin liquids
# moves head down toward chest when swallowing
# has food or liquid come out of nose when eating
# gets pale or blue color around his/her lips during meals
# breathes faster or harder when eating
# needs to take a break during the meal to rest or catch their breath
# gets tired from eating and is not able to finish
# sweats/gets clammy during meals
# tilts head back while eating
# burps more than usual while eating
# throws up during mealtime
# throws up between meals (from 30 minutes after the last meal until the next 17. meal)
# arches back during or after meals
# gags when it is time to eat (for example, when they see food or when placed in 19. high chair)
# gags with smooth foods like pudding
# gags with textured food like coarse oatmeal
# gags, coughs, or vomits when brushing teeth (if your child does not have teeth, 22. select Never. If your child will not allow you to brush his/her teeth, select Always)
# gets a bloated tummy after eating
# turns red in face, may cry with stooling
# has gas
# drools when eating
# has a hard time eating due to stuffy nose
# avoids eating by playing or talking
# has to be told to start eating
# has to be reminded to keep eating
# won't eat at meals, but wants food later
# stops eating after a few bites
# refuses to eat
# shows more stress during meals than during non-meal times (whines, cries, 34. gets angry, tantrums)
# insists on food being offered in a certain way (such as, how food is on the plate 36. or what dish or spoon is used, or where they sit)
# insists on being fed by the same person(s)
# becomes upset by the smell of food
# throws food or pushes food away
# prefers to drink instead of eat
# prefers crunchy foods
# eats better when entertained
# takes more than 30 minutes to eat
# needs mealtime to be calm
# wants the same food for more than two weeks in a row
# likes to eat
# eats a variety of foods (fruits, vegetables, proteins, etc.)
# is willing to stay seated during mealtime
# opens their mouth when food is offered
# is willing to touch food with their hands
# will eat mixed texture foods
# will eat food warmer than room temperature
# is willing to feed self (if younger in age, holds cup, feeds self crackers)
# keeps food in mouth when eating (food means non-liquids)
# keeps liquids in mouth when drinking
# keeps their tongue inside mouth during eating
# acts hungry before meals
# will eat foods that need to be chewed
# will eat textured food like coarse oatmeal
# will eat frozen food, like ice cream
# chews their food enough
# moves food in their mouth when chewing without help
# sniffs food or objects
# spits food out
# eats too fast
# stores food in their cheek or roof of mouth
# gets food stuck in their cheek or roof of mouth
# prefers smooth foods like yogurt
# puts too much food in mouth at one time
# puts fingers in mouth to move food
# prefers strong flavors
# bites down on the spoon or fork and does not release it easily
# grinds teeth when awake (if your child does not have teeth, please select 73. Never.
# chews on toys, clothes, or other objects
# has to be reminded to chew food
# sucks on food to soften or moisten it, rather than chewing it
# chews food but doesn't swallow it
# chews a bite of food for a long time (~30 seconds or longer)

# %%
observation_schema = Literal["physiologic_symtoms", "problematic_mealtime_bahaviors", "selective_restrictive_eating", "oral_processing"]
score_schema = Literal['asc_scoring', 'desc_scoring']
observations_keys_schema = Literal['observations', 'total_score']
observation_schema = Literal['description', 'score']

pediate_observations_schema = dict[observation_schema, dict[score_schema, dict[observations_keys_schema, str | list[dict[observation_schema]]]]]

pediate_observations: pediate_observations_schema = {
    "physiologic_symtoms": {
        "asc_scoring": {
            "observations": [
                {
                    "description"
                }
            ],
            "score": ""
        },
        "desc_scoring": {
            "observations": [],
            "score": ""
        }
    },
    "problematic_mealtime_bahaviors": {
        "asc_scoring": {
            "observations": [

            ],
            "score": ""
        },
        "desc_scoring": {
            "observations": [],
            "score": ""
        }
    },
    "selective_restrictive_eating": {
        "asc_scoring": {
            "observations": [

            ],
            "score": ""
        },
        "desc_scoring": {
            "observations": [],
            "score": ""
        }
    },
    "oral_processing": {
        "asc_scoring": {
            "observations": [

            ],
            "score": ""
        },
        "desc_scoring": {
            "observations": [],
            "score": ""
        }
    }
}

# %%
for x in observation_scores:
    print(" ----> ".join(x[::-1]))
# Out:
# 2 ----> 1. gets watery eyes when eating
# 0 ----> 2. gets red color around eyes or face when eating
# 2 ----> 3. coughs during or after eating
# 1 ----> sounds gurgly or like they need to cough or clear their throat during or after 4. eating
# 0 ----> sounds different during or after a meal (for example, voice becomes hoarse, 5. high-pitched, or quiet)
# 2 ----> 6. chokes or coughs on water or other thin liquids
# 2 ----> 7. moves head down toward chest when swallowing
# 4 ----> 8. has food or liquid come out of nose when eating
# 0 ----> 9. gets pale or blue color around his/her lips during meals
# 1 ----> 10. breathes faster or harder when eating
# 5 ----> 11. needs to take a break during the meal to rest or catch their breath
# 1 ----> 12. gets tired from eating and is not able to finish
# 1 ----> 13. sweats/gets clammy during meals
# 1 ----> 14. tilts head back while eating
# 1 ----> 15. burps more than usual while eating
# 0 ----> 16. throws up during mealtime
# 1 ----> throws up between meals (from 30 minutes after the last meal until the next 17. meal)
# 2 ----> 18. arches back during or after meals
# 0 ----> gags when it is time to eat (for example, when they see food or when placed in 19. high chair)
# 0 ----> 20. gags with smooth foods like pudding
# 1 ----> 21. gags with textured food like coarse oatmeal
# 0 ----> gags, coughs, or vomits when brushing teeth (if your child does not have teeth, 22. select Never. If your child will not allow you to brush his/her teeth, select Always)
# 1 ----> 23. gets a bloated tummy after eating
# 0 ----> 24. turns red in face, may cry with stooling
# 0 ----> 25. has gas
# 3 ----> 26. drools when eating
# 5 ----> 27. has a hard time eating due to stuffy nose
# 0 ----> 28. avoids eating by playing or talking
# 0 ----> 29. has to be told to start eating
# 3 ----> 30. has to be reminded to keep eating
# 0 ----> 31. won't eat at meals, but wants food later
# 0 ----> 32. stops eating after a few bites
# 0 ----> 33. refuses to eat
# 0 ----> shows more stress during meals than during non-meal times (whines, cries, 34. gets angry, tantrums)
# 3 ----> insists on food being offered in a certain way (such as, how food is on the plate 36. or what dish or spoon is used, or where they sit)
# 0 ----> 37. insists on being fed by the same person(s)
# 0 ----> 38. becomes upset by the smell of food
# 3 ----> 39. throws food or pushes food away
# 1 ----> 40. prefers to drink instead of eat
# 0 ----> 41. prefers crunchy foods
# 2 ----> 42. eats better when entertained
# 2 ----> 43. takes more than 30 minutes to eat
# 2 ----> 44. needs mealtime to be calm
# 1 ----> 45. wants the same food for more than two weeks in a row
# 5 ----> 46. likes to eat
# 5 ----> 47. eats a variety of foods (fruits, vegetables, proteins, etc.)
# 5 ----> 48. is willing to stay seated during mealtime
# 5 ----> 49. opens their mouth when food is offered
# 5 ----> 50. is willing to touch food with their hands
# 5 ----> 51. will eat mixed texture foods
# 5 ----> 52. will eat food warmer than room temperature
# 0 ----> 53. is willing to feed self (if younger in age, holds cup, feeds self crackers)
# 2 ----> 54. keeps food in mouth when eating (food means non-liquids)
# 0 ----> 55. keeps liquids in mouth when drinking
# 1 ----> 56. keeps their tongue inside mouth during eating
# 0 ----> 57. acts hungry before meals
# 3 ----> 58. will eat foods that need to be chewed
# 2 ----> 59. will eat textured food like coarse oatmeal
# 0 ----> 60. will eat frozen food, like ice cream
# 1 ----> 61. chews their food enough
# 3 ----> 62. moves food in their mouth when chewing without help
# 0 ----> 63. sniffs food or objects
# 3 ----> 64. spits food out
# 2 ----> 65. eats too fast
# 2 ----> 66. stores food in their cheek or roof of mouth
# 1 ----> 67. gets food stuck in their cheek or roof of mouth
# 1 ----> 68. prefers smooth foods like yogurt
# 1 ----> 69. puts too much food in mouth at one time
# 0 ----> 70. puts fingers in mouth to move food
# 0 ----> 71. prefers strong flavors
# 3 ----> 72. bites down on the spoon or fork and does not release it easily
# 1 ----> grinds teeth when awake (if your child does not have teeth, please select 73. Never.
# 0 ----> 74. chews on toys, clothes, or other objects
# 2 ----> 75. has to be reminded to chew food
# 3 ----> 76. sucks on food to soften or moisten it, rather than chewing it
# 1 ----> 77. chews food but doesn't swallow it
# 0 ----> 78. chews a bite of food for a long time (~30 seconds or longer)

# %%
def clean_sentence(text: str) -> str:
    cleaned_text = re.sub(r'^\d+\.\s+', '', text)
    return cleaned_text

# %%
for o in observation_scores:
    print(o[0])
# Out:
# 1. gets watery eyes when eating
# 2. gets red color around eyes or face when eating
# 3. coughs during or after eating
# sounds gurgly or like they need to cough or clear their throat during or after 4. eating
# sounds different during or after a meal (for example, voice becomes hoarse, 5. high-pitched, or quiet)
# 6. chokes or coughs on water or other thin liquids
# 7. moves head down toward chest when swallowing
# 8. has food or liquid come out of nose when eating
# 9. gets pale or blue color around his/her lips during meals
# 10. breathes faster or harder when eating
# 11. needs to take a break during the meal to rest or catch their breath
# 12. gets tired from eating and is not able to finish
# 13. sweats/gets clammy during meals
# 14. tilts head back while eating
# 15. burps more than usual while eating
# 16. throws up during mealtime
# throws up between meals (from 30 minutes after the last meal until the next 17. meal)
# 18. arches back during or after meals
# gags when it is time to eat (for example, when they see food or when placed in 19. high chair)
# 20. gags with smooth foods like pudding
# 21. gags with textured food like coarse oatmeal
# gags, coughs, or vomits when brushing teeth (if your child does not have teeth, 22. select Never. If your child will not allow you to brush his/her teeth, select Always)
# 23. gets a bloated tummy after eating
# 24. turns red in face, may cry with stooling
# 25. has gas
# 26. drools when eating
# 27. has a hard time eating due to stuffy nose
# 28. avoids eating by playing or talking
# 29. has to be told to start eating
# 30. has to be reminded to keep eating
# 31. won't eat at meals, but wants food later
# 32. stops eating after a few bites
# 33. refuses to eat
# shows more stress during meals than during non-meal times (whines, cries, 34. gets angry, tantrums)
# insists on food being offered in a certain way (such as, how food is on the plate 36. or what dish or spoon is used, or where they sit)
# 37. insists on being fed by the same person(s)
# 38. becomes upset by the smell of food
# 39. throws food or pushes food away
# 40. prefers to drink instead of eat
# 41. prefers crunchy foods
# 42. eats better when entertained
# 43. takes more than 30 minutes to eat
# 44. needs mealtime to be calm
# 45. wants the same food for more than two weeks in a row
# 46. likes to eat
# 47. eats a variety of foods (fruits, vegetables, proteins, etc.)
# 48. is willing to stay seated during mealtime
# 49. opens their mouth when food is offered
# 50. is willing to touch food with their hands
# 51. will eat mixed texture foods
# 52. will eat food warmer than room temperature
# 53. is willing to feed self (if younger in age, holds cup, feeds self crackers)
# 54. keeps food in mouth when eating (food means non-liquids)
# 55. keeps liquids in mouth when drinking
# 56. keeps their tongue inside mouth during eating
# 57. acts hungry before meals
# 58. will eat foods that need to be chewed
# 59. will eat textured food like coarse oatmeal
# 60. will eat frozen food, like ice cream
# 61. chews their food enough
# 62. moves food in their mouth when chewing without help
# 63. sniffs food or objects
# 64. spits food out
# 65. eats too fast
# 66. stores food in their cheek or roof of mouth
# 67. gets food stuck in their cheek or roof of mouth
# 68. prefers smooth foods like yogurt
# 69. puts too much food in mouth at one time
# 70. puts fingers in mouth to move food
# 71. prefers strong flavors
# 72. bites down on the spoon or fork and does not release it easily
# grinds teeth when awake (if your child does not have teeth, please select 73. Never.
# 74. chews on toys, clothes, or other objects
# 75. has to be reminded to chew food
# 76. sucks on food to soften or moisten it, rather than chewing it
# 77. chews food but doesn't swallow it
# 78. chews a bite of food for a long time (~30 seconds or longer)

# %%
REVERSE_SCORING_QUESTION = [
    "likes to eat",
    "eats a variety of foods (fruits, vegetables, proteins, etc.)",
    "is willing to stay seated during mealtime",
    "opens their mouth when food is offered",
    "is willing to touch food with their hands",
    "will eat mixed texture foods",
    "will eat food warmer than room temperature",
    "is willing to feed self (if younger in age, holds cup, feeds self crackers)",
    "keeps food in mouth when eating (food means non-liquids)",
    "keeps liquids in mouth when drinking",
    "keeps their tongue inside mouth during eating",
    "acts hungry before meals",
    "will eat foods that need to be chewed",
    "will eat textured food like coarse oatmeal",
    "will eat frozen food, like ice cream",
    "chews their food enough",
    "moves food in their mouth when chewing without help"
]
PHYSIOLOGIC_SYMTOMS = [
    "gets watery eyes when eating",
    "gets red color around eyes or face when eating",
    "coughs during or after eating",
    "sounds gurgly or like they need to cough or clear their throat during or after 4. eating",
    "sounds different during or after a meal (for example, voice becomes hoarse, 5. high-pitched, or quiet)",
    "chokes or coughs on water or other thin liquids",
    "moves head down toward chest when swallowing",
    "has food or liquid come out of nose when eating",
    "gets pale or blue color around his/her lips during meals",
    "breathes faster or harder when eating",
    "needs to take a break during the meal to rest or catch their breath",
    "gets tired from eating and is not able to finish",
    "sweats/gets clammy during meals",
    "tilts head back while eating",
    "burps more than usual while eating",
    "throws up during mealtime",
    "throws up between meals (from 30 minutes after the last meal until the next 17. meal)",
    "arches back during or after meals",
    "gags when it is time to eat (for example, when they see food or when placed in 19. high chair)",
    "gags with smooth foods like pudding",
    "gags with textured food like coarse oatmeal",
    "gags, coughs, or vomits when brushing teeth (if your child does not have teeth, 22. select Never. If your child will not allow you to brush his/her teeth, select Always)",
    "gets a bloated tummy after eating",
    "turns red in face, may cry with stooling",
    "has gas",
    "drools when eating",
    "has a hard time eating due to stuffy nose"
]
PROBLEMATIC_MEALTIME_BEHAVIORS = [
    "avoids eating by playing or talking",
    "has to be told to start eating",
    "has to be reminded to keep eating",
    "won't eat at meals, but wants food later",
    "stops eating after a few bites",
    "refuses to eat",
    "shows more stress during meals than during non-meal times (whines, cries, 34. gets angry, tantrums)",
    "insists on food being offered in a certain way (such as, how food is on the plate 36. or what dish or spoon is used, or where they sit)",
    "insists on being fed by the same person(s)",
    "becomes upset by the smell of food",
    "throws food or pushes food away",
    "prefers to drink instead of eat",
    "prefers crunchy foods",
    "eats better when entertained",
    "takes more than 30 minutes to eat",
    "needs mealtime to be calm",
    "wants the same food for more than two weeks in a row",
    "likes to eat",
    "eats a variety of foods (fruits, vegetables, proteins, etc.)",
    "is willing to stay seated during mealtime",
    "opens their mouth when food is offered",
    "is willing to touch food with their hands"
]
SELECTIVE_RESTRICTIVE_EATING = [
    "will eat mixed texture foods",
    "will eat food warmer than room temperature",
    "is willing to feed self (if younger in age, holds cup, feeds self crackers)",
    "keeps food in mouth when eating (food means non-liquids)",
    "keeps liquids in mouth when drinking",
    "keeps their tongue inside mouth during eating",
    "acts hungry before meals",
    "will eat foods that need to be chewed",
    "will eat textured food like coarse oatmeal",
    "will eat frozen food, like ice cream",
    "chews their food enough",
    "moves food in their mouth when chewing without help",
    "sniffs food or objects",
    "spits food out",
    "eats too fast"
]
ORAL_PROCESSING = [
    "stores food in their cheek or roof of mouth",
    "gets food stuck in their cheek or roof of mouth",
    "prefers smooth foods like yogurt",
    "puts too much food in mouth at one time",
    "puts fingers in mouth to move food",
    "prefers strong flavors",
    "bites down on the spoon or fork and does not release it easily",
    "grinds teeth when awake (if your child does not have teeth, please select 73. Never.",
    "chews on toys, clothes, or other objects",
    "has to be reminded to chew food",
    "sucks on food to soften or moisten it, rather than chewing it",
    "chews food but doesn't swallow it",
    "chews a bite of food for a long time (~30 seconds or longer)",
]

# %%
def create_json_structure():
    for ob in observation_scores:
        if len(ob) == 2:
            ob_sentence, ob_score = ob[0], ob[1]
            ob_sentence = clean_sentence(ob_sentence).strip()
            if ob_sentence in PROBLEMATIC_MEALTIME_BEHAVIORS:
                if ob_sentence in REVERSE_SCORING_QUESTION:
                    pediate_observations['problematic_mealtime_bahaviors']['desc_scoring']['observations'].append({'description': ob_sentence, "score": ob_score})
                else:
                    pediate_observations['problematic_mealtime_bahaviors']['asc_scoring']['observations'].append({'description': ob_sentence, "score": ob_score})
            if ob_sentence in PHYSIOLOGIC_SYMTOMS:
                if ob_sentence in REVERSE_SCORING_QUESTION:
                    pediate_observations['physiologic_symtoms']['desc_scoring']['observations'].append({'description': ob_sentence, "score": ob_score})
                else:
                    pediate_observations['physiologic_symtoms']['asc_scoring']['observations'].append({'description': ob_sentence, "score": ob_score})
            if ob_sentence in ORAL_PROCESSING:
                if ob_sentence in REVERSE_SCORING_QUESTION:
                    pediate_observations['oral_processing']['desc_scoring']['observations'].append({'description': ob_sentence, "score": ob_score})
                else:
                    pediate_observations['oral_processing']['asc_scoring']['observations'].append({'description': ob_sentence, "score": ob_score})
            if ob_sentence in SELECTIVE_RESTRICTIVE_EATING:
                if ob_sentence in REVERSE_SCORING_QUESTION:
                    pediate_observations['selective_restrictive_eating']['desc_scoring']['observations'].append({'description': ob_sentence, "score": ob_score})
                else:
                    pediate_observations['selective_restrictive_eating']['asc_scoring']['observations'].append({'description': ob_sentence, "score": ob_score})
    
    def calculate_total_score():
        for

# %%
print(json.dumps(pediate_observations, indent=4))
# Out:
# {
#     "physiologic_symtoms": {
#         "asc_scoring": {
#             "observations": [
#                 {
#                     "description": "gets watery eyes when eating",
#                     "score": "2"
#                 },
#                 {
#                     "description": "gets red color around eyes or face when eating",
#                     "score": "0"
#                 },
#                 {
#                     "description": "coughs during or after eating",
#                     "score": "2"
#                 },
#                 {
#                     "description": "sounds gurgly or like they need to cough or clear their throat during or after 4. eating",
#                     "score": "1"
#                 },
#                 {
#                     "description": "sounds different during or after a meal (for example, voice becomes hoarse, 5. high-pitched, or quiet)",
#                     "score": "0"
#                 },
#                 {
#                     "description": "chokes or coughs on water or other thin liquids",
#                     "score": "2"
#                 },
#                 {
#                     "description": "moves head down toward chest when swallowing",
#                     "score": "2"
#                 },
#                 {
#                     "description": "has food or liquid come out of nose when eating",
#                     "score": "4"
#                 },
#                 {
#                     "description": "gets pale or blue color around his/her lips during meals",
#                     "score": "0"
#                 },
#                 {
#                     "description": "breathes faster or harder when eating",
#                     "score": "1"
#                 },
#                 {
#                     "description": "needs to take a break during the meal to rest or catch their breath",
#                     "score": "5"
#                 },
#                 {
#                     "description": "gets tired from eating and is not able to finish",
#                     "score": "1"
#                 },
#                 {
#                     "description": "sweats/gets clammy during meals",
#                     "score": "1"
#                 },
#                 {
#                     "description": "tilts head back while eating",
#                     "score": "1"
#                 },
#                 {
#                     "description": "burps more than usual while eating",
#                     "score": "1"
#                 },
#                 {
#                     "description": "throws up during mealtime",
#                     "score": "0"
#                 },
#                 {
#                     "description": "throws up between meals (from 30 minutes after the last meal until the next 17. meal)",
#                     "score": "1"
#                 },
#                 {
#                     "description": "arches back during or after meals",
#                     "score": "2"
#                 },
#                 {
#                     "description": "gags when it is time to eat (for example, when they see food or when placed in 19. high chair)",
#                     "score": "0"
#                 },
#                 {
#                     "description": "gags with smooth foods like pudding",
#                     "score": "0"
#                 },
#                 {
#                     "description": "gags with textured food like coarse oatmeal",
#                     "score": "1"
#                 },
#                 {
#                     "description": "gags, coughs, or vomits when brushing teeth (if your child does not have teeth, 22. select Never. If your child will not allow you to brush his/her teeth, select Always)",
#                     "score": "0"
#                 },
#                 {
#                     "description": "gets a bloated tummy after eating",
#                     "score": "1"
#                 },
#                 {
#                     "description": "turns red in face, may cry with stooling",
#                     "score": "0"
#                 },
#                 {
#                     "description": "has gas",
#                     "score": "0"
#                 },
#                 {
#                     "description": "drools when eating",
#                     "score": "3"
#                 },
#                 {
#                     "description": "has a hard time eating due to stuffy nose",
#                     "score": "5"
#                 }
#             ],
#             "score": ""
#         },
#         "desc_scoring": {
#             "observations": [],
#             "score": ""
#         }
#     },
#     "problematic_mealtime_bahaviors": {
#         "asc_scoring": {
#             "observations": [
#                 {
#                     "description": "avoids eating by playing or talking",
#                     "score": "0"
#                 },
#                 {
#                     "description": "has to be told to start eating",
#                     "score": "0"
#                 },
#                 {
#                     "description": "has to be reminded to keep eating",
#                     "score": "3"
#                 },
#                 {
#                     "description": "won't eat at meals, but wants food later",
#                     "score": "0"
#                 },
#                 {
#                     "description": "stops eating after a few bites",
#                     "score": "0"
#                 },
#                 {
#                     "description": "refuses to eat",
#                     "score": "0"
#                 },
#                 {
#                     "description": "shows more stress during meals than during non-meal times (whines, cries, 34. gets angry, tantrums)",
#                     "score": "0"
#                 },
#                 {
#                     "description": "insists on food being offered in a certain way (such as, how food is on the plate 36. or what dish or spoon is used, or where they sit)",
#                     "score": "3"
#                 },
#                 {
#                     "description": "insists on being fed by the same person(s)",
#                     "score": "0"
#                 },
#                 {
#                     "description": "becomes upset by the smell of food",
#                     "score": "0"
#                 },
#                 {
#                     "description": "throws food or pushes food away",
#                     "score": "3"
#                 },
#                 {
#                     "description": "prefers to drink instead of eat",
#                     "score": "1"
#                 },
#                 {
#                     "description": "prefers crunchy foods",
#                     "score": "0"
#                 },
#                 {
#                     "description": "eats better when entertained",
#                     "score": "2"
#                 },
#                 {
#                     "description": "takes more than 30 minutes to eat",
#                     "score": "2"
#                 },
#                 {
#                     "description": "needs mealtime to be calm",
#                     "score": "2"
#                 },
#                 {
#                     "description": "wants the same food for more than two weeks in a row",
#                     "score": "1"
#                 }
#             ],
#             "score": ""
#         },
#         "desc_scoring": {
#             "observations": [
#                 {
#                     "description": "likes to eat",
#                     "score": "5"
#                 },
#                 {
#                     "description": "eats a variety of foods (fruits, vegetables, proteins, etc.)",
#                     "score": "5"
#                 },
#                 {
#                     "description": "is willing to stay seated during mealtime",
#                     "score": "5"
#                 },
#                 {
#                     "description": "opens their mouth when food is offered",
#                     "score": "5"
#                 },
#                 {
#                     "description": "is willing to touch food with their hands",
#                     "score": "5"
#                 },
#                 {
#                     "description": "likes to eat",
#                     "score": "5"
#                 },
#                 {
#                     "description": "eats a variety of foods (fruits, vegetables, proteins, etc.)",
#                     "score": "5"
#                 },
#                 {
#                     "description": "is willing to stay seated during mealtime",
#                     "score": "5"
#                 },
#                 {
#                     "description": "opens their mouth when food is offered",
#                     "score": "5"
#                 },
#                 {
#                     "description": "is willing to touch food with their hands",
#                     "score": "5"
#                 }
#             ],
#             "score": ""
#         }
#     },
#     "selective_restrictive_eating": {
#         "asc_scoring": {
#             "observations": [
#                 {
#                     "description": "sniffs food or objects",
#                     "score": "0"
#                 },
#                 {
#                     "description": "spits food out",
#                     "score": "3"
#                 },
#                 {
#                     "description": "eats too fast",
#                     "score": "2"
#                 }
#             ],
#             "score": ""
#         },
#         "desc_scoring": {
#             "observations": [
#                 {
#                     "description": "will eat mixed texture foods",
#                     "score": "5"
#                 },
#                 {
#                     "description": "will eat food warmer than room temperature",
#                     "score": "5"
#                 },
#                 {
#                     "description": "is willing to feed self (if younger in age, holds cup, feeds self crackers)",
#                     "score": "0"
#                 },
#                 {
#                     "description": "keeps food in mouth when eating (food means non-liquids)",
#                     "score": "2"
#                 },
#                 {
#                     "description": "keeps liquids in mouth when drinking",
#                     "score": "0"
#                 },
#                 {
#                     "description": "keeps their tongue inside mouth during eating",
#                     "score": "1"
#                 },
#                 {
#                     "description": "acts hungry before meals",
#                     "score": "0"
#                 },
#                 {
#                     "description": "will eat foods that need to be chewed",
#                     "score": "3"
#                 },
#                 {
#                     "description": "will eat textured food like coarse oatmeal",
#                     "score": "2"
#                 },
#                 {
#                     "description": "will eat frozen food, like ice cream",
#                     "score": "0"
#                 },
#                 {
#                     "description": "chews their food enough",
#                     "score": "1"
#                 },
#                 {
#                     "description": "moves food in their mouth when chewing without help",
#                     "score": "3"
#                 }
#             ],
#             "score": ""
#         }
#     },
#     "oral_processing": {
#         "asc_scoring": {
#             "observations": [
#                 {
#                     "description": "stores food in their cheek or roof of mouth",
#                     "score": "2"
#                 },
#                 {
#                     "description": "gets food stuck in their cheek or roof of mouth",
#                     "score": "1"
#                 },
#                 {
#                     "description": "prefers smooth foods like yogurt",
#                     "score": "1"
#                 },
#                 {
#                     "description": "puts too much food in mouth at one time",
#                     "score": "1"
#                 },
#                 {
#                     "description": "puts fingers in mouth to move food",
#                     "score": "0"
#                 },
#                 {
#                     "description": "prefers strong flavors",
#                     "score": "0"
#                 },
#                 {
#                     "description": "bites down on the spoon or fork and does not release it easily",
#                     "score": "3"
#                 },
#                 {
#                     "description": "grinds teeth when awake (if your child does not have teeth, please select 73. Never.",
#                     "score": "1"
#                 },
#                 {
#                     "description": "chews on toys, clothes, or other objects",
#                     "score": "0"
#                 },
#                 {
#                     "description": "has to be reminded to chew food",
#                     "score": "2"
#                 },
#                 {
#                     "description": "sucks on food to soften or moisten it, rather than chewing it",
#                     "score": "3"
#                 },
#                 {
#                     "description": "chews food but doesn't swallow it",
#                     "score": "1"
#                 },
#                 {
#                     "description": "chews a bite of food for a long time (~30 seconds or longer)",
#                     "score": "0"
#                 }
#             ],
#             "score": ""
#         },
#         "desc_scoring": {
#             "observations": [],
#             "score": ""
#         }
#     }
# }

# %%
# Out:
# list
